# %% [markdown]
# # India Food Delivery Project

# %% [markdown]
# Este projeto analisa um dataset de aplicativo de entrega de comida na Índia. Inclui uma análise preliminar, a limpeza e a transformação de dados para a análise completa. O dataset foi retirado de https://www.kaggle.com/datasets/gauravmalik26/food-delivery-dataset

# %% [markdown]
# ## Iniciando o Dataframe

# %%
# importa a biblioteca pandas
import pandas as pd

# %%
# seleciona o arquivo do dataset
df_raw = pd.read_csv('./dataset/india_food_delivery_dataset_train.csv')

# %%
# faz uma cópia do dataframe de backup
df = df_raw.copy()

# %%
# apresenta as informações do dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45593 entries, 0 to 45592
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45593 non-null  object
#  1   Delivery_person_ID           45593 non-null  object
#  2   Delivery_person_Age          45593 non-null  object
#  3   Delivery_person_Ratings      45593 non-null  object
#  4   Restaurant_latitude          45593 non-null  float64
#  5   Restaurant_longitude         45593 non-null  float64
#  6   Delivery_location_latitude   45593 non-null  float64
#  7   Delivery_location_longitude  45593 non-null  float64
#  8   Order_Date                   45593 non-null  object
#  9   Time_Orderd                  45593 non-null  object
#  10  Time_Order_picked            45593 non-null  object
#  11  Weatherconditions            45593 non-null  object
# ...

# %%
# imprime as 5 primeiras linhas
df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# ## Inspeção do Dataframe

# %%
# imprime a forma do dataframe
df.shape
# Out:
# (45593, 20)

# %%
# imprime as 5 primeiras linhas
df.head()
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                     4.9
# 1  0xb379     BANGRES18DEL02                   34                     4.5
# 2  0x5d6d     BANGRES19DEL01                   23                     4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4  0x70a2     CHENRES12DEL01                   32                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
# imprime as 5 últimas linhas
df.tail()
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 45588            26.902328             75.794257                   26.912328
# 45589             0.000000              0.000000                    0.070000
# 45590            13.022394             80.242439                   13.052394
# 45591            11.001753             76.986241                   11.041753
# 45592            23.351058             85.325731                   23.431058
#
# ...

# %%
# imprime os tipos de variáveis
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %% [markdown]
# ## Análise de Negócio 1

# %%
# Qual o valor da informação armazenada na linha 30 e na coluna 10?
df.iloc[30, 10]
# Out:
# '22:40:00'

# %%
# Selecione as linhas 0 a 20 e as colunas 0 a 2
df.iloc[0:20, 0:2]
# Out:
#          ID Delivery_person_ID
# 0   0x4607     INDORES13DEL02
# 1   0xb379     BANGRES18DEL02
# 2   0x5d6d     BANGRES19DEL01
# 3   0x7a6a    COIMBRES13DEL02
# 4   0x70a2     CHENRES12DEL01
# 5   0x9bb4      HYDRES09DEL03
# 6   0x95b4   RANCHIRES15DEL01
# 7   0x9eb2      MYSRES15DEL02
# 8   0x1102      HYDRES05DEL02
# 9   0xcdcd      DEHRES17DEL01
# 10  0xd987      KOCRES16DEL01
# 11  0x2784     PUNERES13DEL03
# 12  0xc8b6     LUDHRES15DEL02
# 13  0xdb64      KNPRES14DEL02
# 14  0x3af3      MUMRES15DEL03
# 15  0x3aab      MYSRES01DEL01
# 16  0x689b     PUNERES20DEL01
# 17  0x6f67      HYDRES14DEL01
# 18  0xc9cf      KOLRES15DEL03
# 19  0x36b8     PUNERES19DEL02

# %%
# Seleciona as linhas 5 a 30 e a coluna “Delivery_person_Age”
df.loc[5:30, 'Delivery_person_Age']
# Out:
# 5     22
# 6     33
# 7     35
# 8     22
# 9     36
# 10    21
# 11    23
# 12    34
# 13    24
# 14    29
# 15    35
# 16    33
# 17    34
# 18    21
# 19    25
# 20    31
# 21    37
# 22    33
# 23    25
# 24    29
# 25    27
# 26    35
# 27    32
# 28    23
# 29    31
# 30    36
# Name: Delivery_person_Age, dtype: object

# %%
# Selecione as linhas 40 a 42 e as seguintes colunas: “Restaurant_latitude”,
# “Restaurant_longitude”, "Delivery_location_latitude”,
# “Delivery_location_longitude”
df.loc[40:42, ['Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude']]
# Out:
#     Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 40            12.972532             77.608179                   13.042532
# 41            13.064181             80.236442                   13.134181
# 42            19.121999             72.908493                   19.201999
#
#     Delivery_location_longitude
# 40                    77.678179
# 41                    80.306442
# 42                    72.988493

# %%
# Qual a menor data de entrega da coluna “Order_Date” entre as linhas 0 a 50?
df.loc[0:50, 'Order_Date'].min()
# Out:
# '01-03-2022'

# %%
# Qual a menor data de entrega da coluna “ Time_Orderd” entre as linhas 0 a 50?
df.loc[0:50, 'Time_Orderd'].min()
# Out:
# '08:15:00'

# %%
# Quais os nomes únicos da coluna “City” entre as linhas 50 e 70?
df.loc[50:70, 'City'].unique()[0]
# Out:
# 'Metropolitian '

# %%
# Quais os nomes únicos da coluna “Weatherconditions” entre as linhas 0 e 10?
list(df.loc[0:10, 'Weatherconditions'].unique())
# Out:
# ['conditions Sunny',
#  'conditions Stormy',
#  'conditions Sandstorms',
#  'conditions Cloudy',
#  'conditions Fog']

# %%
# Quais os tipos de densidade de trânsito presente na coluna
# “Road_traffic_density” entre as linhas 0 a 20?
list(df.loc[0:20, 'Road_traffic_density'].unique())
# Out:
# ['High ', 'Jam ', 'Low ', 'Medium ']

# %%
# Qual o ID do entregador de comida mais velho entre as colunas 50 e 70?
df.loc[df.loc[50:70, 'Delivery_person_Age'].idxmax(), 'ID'].strip()
# Out:
# '0xddc5'

# %%
# Qual o ID do entregador de comida com a melhor avaliação de entrega entre as
# colunas 50 e 70?
df.loc[df.loc[50:70, 'Delivery_person_Ratings'].idxmax(), 'ID'].strip()
# Out:
# '0xc1ff'

# %%
# Quais os tipos de veículos utilizados pelos entregadores entre as linhas 0
# a 30?
list(df.loc[0:30, 'Type_of_vehicle'].unique())
# Out:
# ['motorcycle ', 'scooter ', 'electric_scooter ']

# %%
# Quais os tipos de pedidos único que foram entregues entre as colunas 100 e
# 120?
list(df.loc[100:120, 'Type_of_order'].unique())
# Out:
# ['Snack ', 'Meal ', 'Buffet ', 'Drinks ']

# %% [markdown]
# ## Limpeza de Dados

# %%
df.shape
# Out:
# (45593, 20)

# %%
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age             object
# Delivery_person_Ratings         object
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weatherconditions               object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries             object
# Festival                        object
# City                            object
# Time_taken(min)                 object
# dtype: object

# %%
# remoção das linhas com NaN

# na coluna Delivery_person_Age
df = df.loc[df['Delivery_person_Age'] != 'NaN ', :].copy()

# na coluna Festival
df = df.loc[df['Festival'] != 'NaN ', :].copy()

# na coluna City
df = df.loc[df['City'] != 'NaN ', :].copy()

# na coluna Road_traffic_density
df = df.loc[df['Road_traffic_density'] != 'NaN ', :].copy()

# na coluna multiple_deliveries
df = df.loc[df['multiple_deliveries'] != 'NaN ', :].copy()

# %%
df.shape
# Out:
# (41419, 20)

# %%
# remoção do espaço ao final das strings

# na coluna ID
# df.loc[:, 'ID'] = df.loc[:, 'ID'].str.strip()
df['ID'] = df.loc[:, 'ID'].str.strip()

# na coluna Delivery_person_ID
# df.loc[:, 'Delivery_person_ID'] = df.loc[:, 'Delivery_person_ID'].str.strip()
df['Delivery_person_ID'] = df.loc[:, 'Delivery_person_ID'].str.strip()

# na coluna Road_traffic_density
# df.loc[:, 'Road_traffic_density'] = df.loc[:, 'Road_traffic_density'].str.strip()
df['Road_traffic_density'] = df.loc[:, 'Road_traffic_density'].str.strip()

# na coluna Type_of_order
# df.loc[:, 'Type_of_order'] = df.loc[:, 'Type_of_order'].str.strip()
df['Type_of_order'] = df.loc[:, 'Type_of_order'].str.strip()

# na coluna Type_of_vehicle
# df.loc[:, 'Type_of_vehicle'] = df.loc[:, 'Type_of_vehicle'].str.strip()
df['Type_of_vehicle'] = df.loc[:, 'Type_of_vehicle'].str.strip()

# na coluna Festival
# df.loc[:, 'Festival'] = df.loc[:, 'Festival'].str.strip()
df['Festival'] = df.loc[:, 'Festival'].str.strip()

# na coluna City
# df.loc[:, 'City'] = df.loc[:, 'City'].str.strip()
df['City'] = df.loc[:, 'City'].str.strip()

# %%
# remoção do texto extra das strings

# na coluna Time_taken(min)
df['Time_taken(min)'] = df['Time_taken(min)'].apply(lambda x: x.split('(min) ')[1])

# na coluna Weatherconditions
df['Weatherconditions'] = df['Weatherconditions'].apply(lambda x: x.split('conditions ')[1])

# %%
# conversão de tipos

# na coluna Age para int
df['Delivery_person_Age'] = df['Delivery_person_Age'].astype(int)

# na coluna Ratings para float
df['Delivery_person_Ratings'] = df['Delivery_person_Ratings'].astype(float)

# na coluna Order_Date para datetime
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')

# na coluna multiple_deliveries para datetime
df['multiple_deliveries'] = df['multiple_deliveries'].astype(int)

df['Time_taken(min)'] = df['Time_taken(min)'].astype(int)

# %%
# reset index
df = df.reset_index(drop=True)

# %%
df.shape
# Out:
# (41419, 20)

# %%
df.dtypes
# Out:
# ID                                     object
# Delivery_person_ID                     object
# Delivery_person_Age                     int64
# Delivery_person_Ratings               float64
# Restaurant_latitude                   float64
# Restaurant_longitude                  float64
# Delivery_location_latitude            float64
# Delivery_location_longitude           float64
# Order_Date                     datetime64[ns]
# Time_Orderd                            object
# Time_Order_picked                      object
# Weatherconditions                      object
# Road_traffic_density                   object
# Vehicle_condition                       int64
# Type_of_order                          object
# Type_of_vehicle                        object
# multiple_deliveries                     int64
# Festival                               object
# City                                   object
# Time_taken(min)                         int64
# dtype: object

# %%
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x4607     INDORES13DEL02                   37                      4.9
# 1  0xb379     BANGRES18DEL02                   34                      4.5
# 2  0x5d6d     BANGRES19DEL01                   23                      4.4
# 3  0x7a6a    COIMBRES13DEL02                   38                      4.7
# 4  0x70a2     CHENRES12DEL01                   32                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            22.745049             75.892471                   22.765049
# 1            12.913041             77.683237                   13.043041
# 2            12.914264             77.678400                   12.924264
# 3            11.003669             76.976494                   11.053669
# 4            12.972793             80.249982                   13.012793
#
#    Delivery_location_longitude Order_Date Time_Orderd Time_Order_picked  \
# ...

# %% [markdown]
# ## Realizando Agrupamentos

# %%
# Quantidade de entregas por cidade
df.loc[:, ['ID', 'City']].groupby('City').count()
# Out:
#                   ID
# City
# Metropolitian  31863
# Semi-Urban       152
# Urban           9404

# %%
# Média de idade dos entregadores por cidade e por tipo de veículo
df.loc[:, ['Delivery_person_Age', 'City']].groupby(['City']).mean().reset_index()
# Out:
#             City  Delivery_person_Age
# 0  Metropolitian            29.796315
# 1     Semi-Urban            32.565789
# 2          Urban            28.928222

# %%
# Idade mínima dos entregadores por cidade e por tipo de veículo
df.loc[:, ['Delivery_person_Age', 'City', 'Type_of_vehicle']].groupby(['City', 'Type_of_vehicle']).min().reset_index()
# Out:
#             City   Type_of_vehicle  Delivery_person_Age
# 0  Metropolitian  electric_scooter                   20
# 1  Metropolitian        motorcycle                   20
# 2  Metropolitian           scooter                   20
# 3     Semi-Urban  electric_scooter                   34
# 4     Semi-Urban        motorcycle                   20
# 5     Semi-Urban           scooter                   30
# 6          Urban  electric_scooter                   20
# 7          Urban        motorcycle                   20
# 8          Urban           scooter                   20

# %% [markdown]
# ## Análise de Negócio 2

# %%
# Qual o número total de entregas cadastradas na base de dados?
len(df['ID'].unique())
# Out:
# 41419

# %%
# Qual o número total de entregadores únicos cadastrados na base de dados?
len(df['Delivery_person_ID'].unique())
# Out:
# 1320

# %%
# Qual a idade do entregador mais velho? E do mais novo?
print(f"Mais velho: {df.loc[:, 'Delivery_person_Age'].max()}\nMais novo: {df.loc[:, 'Delivery_person_Age'].min()}")
# Out:
# Mais velho: 39
# Mais novo: 20

# %%
# Qual o ID do entregador com a maior idade? E o ID do entregaor com a
# menor idade?
df.loc[df.loc[:, 'Delivery_person_Age'].idxmax(), 'Delivery_person_ID']
# Out:
# 'AGRRES12DEL03'

# %%
# Quais os nomes das condições climáticas?
list(df.loc[:, 'Weatherconditions'].unique())
# Out:
# ['Sunny', 'Stormy', 'Sandstorms', 'Cloudy', 'Fog', 'Windy']

# %%
# Quantas entregas foram realizadas sob condições climáticas de tempestade
# de areia? ( Sandstorms )
df.loc[df['Weatherconditions'] == 'Sandstorms', 'ID'].count()
# Out:
# np.int64(6858)

# %%
# Quais eram as condicões climáticas da data mais recente de entrega?
df.loc[df.loc[:, 'Order_Date'].idxmax(), 'Weatherconditions']
# Out:
# 'Sunny'

# %%
# Quantos tipos de densidade de trânsito existem na base de dados? Quais os
# nomes delas?

# %%
# Quantas entregas foram feitas em cada condição climática?

# %%
# Quantos entregadores únicos fizeram entregas em cada condição climática?

# %%
# Quantas entregas foram feitas em cada tipo de densidade de trânsito?

# %%
# Quantos entregadores únicos fizeram entregas em cada tipo de densidade
# de trânsito?

# %%
# Quantas cidades únicas existem na base? Quais são os seus nomes?

# %%
# Quantos tipos de veículos únicos existem na base?

# %%
# Qual o tipo de veículo que mais vez entregas com a condição de trânsito
# pesado? ( High )

# %%
# Qual o tipo de pedido mais feito durante condições climáticas de tempestade
# de areia?

# %%
# Qual a cidade com o maior número de pedidos de Bebidas (Drinks) feito em
# Scooter?

# %%
# Qual o nome da cidade com o (os) entregador mais velho? E o nome da
# cidade com o (os) entregadores mais novos?

# %%
# Quantas entregas foram feitas durante o Festival?

# %%
# Quantas cidades únicas tiveram entregas feitas durante o Festival?

# %%
# Quantas entregas foram feitas durante o Festival na cidade chamada Urban
# ("Urban")

# %% [markdown]
# ## Análise de Negócio 3

# %%
# Qual o número total de entregadores cadastrados na base de dados?
#df.loc[:, 'Delivery_person_ID'].count()

#df['Delivery_person_ID'].count()

# %%
# Qual o número total de entregadores únicos cadastrados na base de dados?

#df['Delivery_person_ID'].nunique()

# %%
# Qual a média de idade dos entregadores por cidade?

#df.loc[:, ['Delivery_person_Age', 'City']].groupby(['City']).mean()

# %%
# Qual a mediana de idade dos entregadores por cidade?

#df.loc[:, ['Delivery_person_Age', 'City']].groupby(['City']).median()

# %%
# Qual o número total de entregas feitas por densidade de tráfego?

#df.loc[:, ['ID', 'Road_traffic_density']].groupby(['Road_traffic_density']).count()

# %%
# Qual a média das avaliações das entregas feitas por densidade de tráfego?

#df.loc[:, ['ID', 'Road_traffic_density', 'Delivery_person_Ratings']].groupby(['Road_traffic_density']).mean('Delivery_person_Ratings')

# %%
# Qual a quantidade de entregas feitas por cidade?

#df.loc[:, ['ID', 'City']].groupby(['City']).count()

# %%
# Qual a média, mediana e desvio padrão das entregas feitas por cidade e por
# tipo de veículo?

#media = df.loc[:, ['ID', 'City', 'Type_of_vehicle']].groupby(['City', 'Type_of_vehicle']).count()['ID'].mean()
#mediana = df.loc[:, ['ID', 'City', 'Type_of_vehicle']].groupby(['City', 'Type_of_vehicle']).count()['ID'].median()
#desvio_padrao = df.loc[:, ['ID', 'City', 'Type_of_vehicle']].groupby(['City', 'Type_of_vehicle']).count()['ID'].std()
#print(f'A média é {media}\nA mediana é {mediana}\nO desvio padrão é {desvio_padrao}')

# %%
# Qual a primeira data de entrega por cada cidade?

#df.loc[:, ['City', 'Order_Date']].groupby(['City']).min()

# %%
# Qual a última data de entrega por cada cidade?

#df.loc[:, ['City', 'Order_Date']].groupby(['City']).max()

# %%
# Qual a média de avaliações das entregas feitas por condições climáticas?


#df.loc[:, ['Delivery_person_Ratings', 'Weatherconditions']].groupby('Weatherconditions').mean()

# %%
# Qual o valor da avaliação mais baixa feita por tipo de condição climática e
# por densidade de tráfego?

#df.loc[:, ['Delivery_person_Ratings', 'Weatherconditions', 'Road_traffic_density']].groupby(['Weatherconditions', 'Road_traffic_density']).min()

# %%
# Qual a média, mediana e desvio padrão das avaliações por cada tipo de
# condições de veículos?

# %%
# Quantas entregas foram feitas no Festival?

#df.loc[:, ['ID', 'Festival']].groupby(['Festival']).count()

# %%
# Qual a avaliação média das entregas feitas no Festival?

# %%
# Qual a menor avaliação feita em uma entrega no Festival e por cidade?

# %%
# Qual a maior avaliação feita por tipo de pedido?

# %%
# Qual a idade do entregador mais velho da planilha de dados?

# %%
# Qual a idade do entregador mais novo da planilha de dados?

# %%
# Quantas entregas foram feitas em cada condição climática?

# %%
# Quantas entregas foram feitas em cada tipo de densidade de trânsito?

# %% [markdown]
# ## DataViz 1

# %%
# 1.Desenhar um gráfico de pizza com a média de idade dos entregadores
# por cidade

# %%
# 2.Desenhe um gráfico de linha, mostrando o número total de entregas
# diárias feitas por densidade de tráfego igual a “Low” e “Jam”

# %%
# 3.Desenhe um gráfico de barras, mostrando as avaliações médias das
# entregas por semana.

# %%
# 4.Desenhe um gráfico de pizza, mostrando a média de avaliações das
# entregas feitas por condições climáticas?
